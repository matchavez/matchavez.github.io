# %% [markdown]
# ## Markdown

# %%
s = 'Hello, world.'
str(s)
# Out:
# 'Hello, world.'

# %% [markdown]
# This is another _section_.
# We are doing more.
# ### H3
#
# # H1

# %% [markdown]
# This is more Markdown, but it's considered _done_. It's `rendered`.
